# %% [markdown]
# 1. What is function in python?
#     -- Function are block of code which can be used multiple times just by calling it, when required.

# %%
### Functions Example:
def sum(a,b):
  print(a+b)

sum(2,3)
# Out:
# 5
